# %%
import requests
import pandas as pd 
import ipeadatapy as ipea 
from functions import graf_plotly

# %%
ipea.metadata('BM12_PIB12')
# Out:
#          CODE NAME                                            COMMENT  \
# 0  BM12_PIB12  PIB  O Produto Interno Bruto (PIB) denominado como ...
#
#                      LAST UPDATE       BIG THEME           SOURCE ACRONYM  \
# 0  2021-01-27T17:08:00.973-03:00  Macroeconômico  Bacen/Boletim/Ativ. Ec.
#
#                                               SOURCE             SOURCE URL  \
# 0  Banco Central do Brasil, Boletim, Seção Ativid...  http://www.bcb.gov.br
#
#   FREQUENCY MEASURE     UNIT SERIES STATUS  THEME CODE COUNTRY  NUMERICA
# 0    Mensal      R$  milhões             A           8     BRA      True

# %%
pib_describe = ipea.describe('BM12_PIB12')

# %%
pib = ipea.timeseries('BM12_PIB12')
pib = pib['VALUE (R$)']
pib = pd.DataFrame(pib)
pib
# Out:
#             VALUE (R$)
# DATE
# 1990-01-01         0.2
# 1990-02-01         0.4
# 1990-03-01         0.8
# 1990-04-01         0.7
# 1990-05-01         0.8
# ...                ...
# 2020-08-01    630090.4
# 2020-09-01    631329.4
# 2020-10-01    653805.9
# 2020-11-01    652260.0
# 2020-12-01    659897.5
#
# [372 rows x 1 columns]

# %%
pib = pib.rename(columns={"VALUE (R$)": 'PIB Mensal R$'})

# %%
pib
# Out:
#             PIB Mensal R$
# DATE
# 1990-01-01            0.2
# 1990-02-01            0.4
# 1990-03-01            0.8
# 1990-04-01            0.7
# 1990-05-01            0.8
# ...                   ...
# 2020-08-01       630090.4
# 2020-09-01       631329.4
# 2020-10-01       653805.9
# 2020-11-01       652260.0
# 2020-12-01       659897.5
#
# [372 rows x 1 columns]

# %%
graf_plotly(pib, "PIB Mensal em Reais")
